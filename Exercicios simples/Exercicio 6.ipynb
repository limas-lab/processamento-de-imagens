# %%
#Nome do aluno: Davi dos Santos Lima
#RA: 5152118
#Atividade: Exercicio 6

# %%
#Importando as bibliotecas

import numpy as np 
import matplotlib.pyplot as plt  
import imageio as im 
from google.colab import drive  
from matplotlib import pyplot as plt  
import cv2 
from google.colab.patches import cv2_imshow ### para imshow

drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
img_art = '/content/gdrive/MyDrive/PDI/Lab_2/art8.png'
img_bola = '/content/gdrive/MyDrive/PDI/Lab_2/bolafm.jpg'

# %%
image_x = im.imread(img_art) 
plt.imshow(image_x, cmap='gray') 
image_x.size
# Out:
# 65536

# %%
image_x = cv2.imread(img_art, 0) 
plt.imshow(image_x)  
plt.show()

# %%
image_b = im.imread(img_bola) 
plt.imshow(image_b[0,:,:], cmap='gray') 
image_b.size
# Out:
# 518076

# %%
image_b = cv2.imread(img_bola, 0) 
plt.imshow(image_b)  
plt.show()

# %% [markdown]
# ## a) Verificar o número de linhas e colunas da imagem:

# %%
print(f'Numero de linhas e colunas da imagem com X {image_x.shape}')
print(f'Numero de linhas e colunas da imagem da bola {image_b.shape}')
# Out:
# Numero de linhas e colunas da imagem com X (256, 256)
# Numero de linhas e colunas da imagem da bola (351, 492)

# %% [markdown]
# ## b) Atribuir os valores das linhas e colunas às variáveis M e N:

# %%
[M,N] = image_x.shape
print(f'Numero de linhas e colunas da imagem com X {M,N}')

[O,P] = image_b.shape
print(f'Numero de linhas e colunas da imagem da bola {O,P}')
# Out:
# Numero de linhas e colunas da imagem com X (256, 256)
# Numero de linhas e colunas da imagem da bola (351, 492)

# %%
image_b = im.imread(img_bola)

#Antes
#plt.imshow(image_b, cmap='gray')
#Depois
plt.imshow(image_b[0,:,:], cmap='gray')

image_b.size
# Out:
# 518076
