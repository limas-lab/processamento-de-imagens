# %%
#Nome do aluno: Davi dos Santos Lima
#RA: 5152118
#Atividade: Exercicio 7

# %%
#Importando as bibliotecas

import numpy as np 
import matplotlib.pyplot as plt  
import imageio as im 
from google.colab import drive  
from matplotlib import pyplot as plt  
import cv2 
from google.colab.patches import cv2_imshow ### para imshow

from skimage import data, io, filters

drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# # 7) Construa novos programas que empregue as bibliotecas scikit-image, SciPy e SimpleCV  para abrir novas imagens CoLab. Remova 50 pixels de cada lado da imagem e mostre o  resultado.

# %%
plt.rcParams['font.size'] = 18

images = 'hubble_deep_field'

caller = getattr(data, images)
image = caller()
plt.figure()
plt.title(images)

if image.ndim == 2:
  plt.imshow(image, cmap=plt.cm.gray)
else:
  plt.imshow(image)

plt.show()

# %%
lenna = '/content/gdrive/MyDrive/PDI/Lab_2/lenna.jpg'

image = im.imread(lenna)
print(image.shape)

img_array = np.array(image)

img_array[0:240,0:50] = (0,0,0)
img_array[0:50,0:256] = (0,0,0)

plt.imshow(img_array)
# Out:
# (240, 256, 3)
